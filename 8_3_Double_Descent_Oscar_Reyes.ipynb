# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-tt8scamf
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-tt8scamf
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14496 sha256=8dafb6fc4650abd7e68e9731c44c7135dc983aa8c8d936b9108f927015103ae5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sh1cza3b/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# TO DO ANSWERS

# => 1. It will become zero at 10 hidden_variables capacity.

# => 2. It expects to appear at 60 hidden_variables capacity.

# => 3. It expects to appear at 180 hidden_variables capacity.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.294838, train error 88.38,  test loss 2.291132, test error 88.00
# Epoch   100, train loss 1.908881, train error 72.78,  test loss 1.751818, test error 70.05
# Epoch   200, train loss 1.904740, train error 71.32,  test loss 1.750561, test error 69.90
# Epoch   300, train loss 1.903277, train error 71.35,  test loss 1.739792, test error 70.03
# Epoch   400, train loss 1.902540, train error 71.80,  test loss 1.742738, test error 70.18
# Epoch   500, train loss 1.902489, train error 72.38,  test loss 1.734640, test error 69.43
# Epoch   600, train loss 1.904353, train error 72.50,  test loss 1.740075, test error 70.20
# Epoch   700, train loss 1.901593, train error 71.03,  test loss 1.739515, test error 70.12
# Epoch   800, train loss 1.903186, train error 72.20,  test loss 1.737763, test error 70.10
# Epoch   900, train loss 1.902175, train error 71.28,  test loss 1.738474, test error 69.97
# Training model with   4 hidden variables
# Epoch     0, train loss 2.296036, train error 89.12,  test loss 2.300826, test error 89.55
# Epoch   100, train loss 1.837536, train error 69.55,  test loss 1.701917, test error 66.97
# Epoch   200, train loss 1.781641, train error 66.55,  test loss 1.623479, test error 64.88
# Epoch   300, train loss 1.769562, train error 66.18,  test loss 1.608211, test error 64.35
# Epoch   400, train loss 1.756564, train error 65.62,  test loss 1.607912, test error 64.53
# Epoch   500, train loss 1.750569, train error 65.25,  test loss 1.598614, test error 63.70
# Epoch   600, train loss 1.749905, train error 65.18,  test loss 1.601881, test error 63.80
# Epoch   700, train loss 1.742795, train error 64.97,  test loss 1.600753, test error 63.55
# Epoch   800, train loss 1.738455, train error 65.18,  test loss 1.598611, test error 63.17
# Epoch   900, train loss 1.735615, train error 64.93,  test loss 1.589829, test error 62.78
# Training model with   6 hidden variables
# Epoch     0, train loss 2.280580, train error 85.95,  test loss 2.283245, test error 86.53
# Epoch   100, train loss 1.668108, train error 59.20,  test loss 1.554120, test error 59.50
# Epoch   200, train loss 1.638790, train error 58.88,  test loss 1.559111, test error 59.20
# Epoch   300, train loss 1.635029, train error 59.28,  test loss 1.558966, test error 59.15
# Epoch   400, train loss 1.629002, train error 58.72,  test loss 1.551666, test error 58.95
# Epoch   500, train loss 1.623579, train error 58.45,  test loss 1.542565, test error 58.90
# Epoch   600, train loss 1.622696, train error 58.17,  test loss 1.544199, test error 58.83
# Epoch   700, train loss 1.621615, train error 58.65,  test loss 1.560992, test error 59.10
# Epoch   800, train loss 1.617169, train error 58.55,  test loss 1.549660, test error 58.60
# Epoch   900, train loss 1.615961, train error 58.33,  test loss 1.559100, test error 59.05
# Training model with   8 hidden variables
# Epoch     0, train loss 2.278951, train error 88.22,  test loss 2.282700, test error 89.03
# Epoch   100, train loss 1.621628, train error 57.05,  test loss 1.446612, test error 54.75
# Epoch   200, train loss 1.568252, train error 54.78,  test loss 1.409018, test error 54.33
# Epoch   300, train loss 1.543700, train error 53.20,  test loss 1.404557, test error 52.95
# Epoch   400, train loss 1.525764, train error 53.15,  test loss 1.394914, test error 52.45
# Epoch   500, train loss 1.525589, train error 53.33,  test loss 1.403697, test error 52.60
# Epoch   600, train loss 1.512638, train error 53.42,  test loss 1.394729, test error 52.60
# Epoch   700, train loss 1.511825, train error 53.15,  test loss 1.411247, test error 52.53
# Epoch   800, train loss 1.504198, train error 52.70,  test loss 1.416373, test error 53.75
# Epoch   900, train loss 1.504317, train error 53.58,  test loss 1.421174, test error 53.55
# Training model with  10 hidden variables
# Epoch     0, train loss 2.226994, train error 82.60,  test loss 2.214270, test error 81.78
# Epoch   100, train loss 1.551051, train error 53.95,  test loss 1.409407, test error 53.47
# Epoch   200, train loss 1.425594, train error 48.25,  test loss 1.262017, test error 47.35
# Epoch   300, train loss 1.392322, train error 46.28,  test loss 1.248923, test error 46.53
# Epoch   400, train loss 1.381691, train error 46.03,  test loss 1.241640, test error 46.25
# Epoch   500, train loss 1.370360, train error 46.10,  test loss 1.240332, test error 46.75
# Epoch   600, train loss 1.365438, train error 45.20,  test loss 1.251029, test error 46.03
# Epoch   700, train loss 1.361515, train error 45.88,  test loss 1.255378, test error 45.58
# Epoch   800, train loss 1.350221, train error 45.17,  test loss 1.255379, test error 46.42
# Epoch   900, train loss 1.350827, train error 45.12,  test loss 1.252482, test error 45.95
# Training model with  14 hidden variables
# Epoch     0, train loss 2.187999, train error 80.93,  test loss 2.156520, test error 81.07
# Epoch   100, train loss 1.480832, train error 50.42,  test loss 1.402943, test error 53.50
# Epoch   200, train loss 1.406696, train error 48.12,  test loss 1.382909, test error 52.38
# Epoch   300, train loss 1.362024, train error 46.30,  test loss 1.391537, test error 51.60
# Epoch   400, train loss 1.337165, train error 45.28,  test loss 1.418581, test error 52.08
# Epoch   500, train loss 1.322059, train error 44.33,  test loss 1.445179, test error 52.25
# Epoch   600, train loss 1.316276, train error 44.58,  test loss 1.463616, test error 51.53
# Epoch   700, train loss 1.307785, train error 44.83,  test loss 1.487303, test error 52.80
# Epoch   800, train loss 1.303288, train error 44.67,  test loss 1.491644, test error 52.08
# Epoch   900, train loss 1.301337, train error 44.75,  test loss 1.513176, test error 52.45
# Training model with  18 hidden variables
# Epoch     0, train loss 2.151695, train error 81.12,  test loss 2.116091, test error 79.60
# Epoch   100, train loss 1.407745, train error 47.80,  test loss 1.385855, test error 51.83
# Epoch   200, train loss 1.287214, train error 43.22,  test loss 1.363366, test error 50.83
# Epoch   300, train loss 1.241975, train error 42.22,  test loss 1.428689, test error 52.28
# Epoch   400, train loss 1.202916, train error 40.90,  test loss 1.445466, test error 51.65
# Epoch   500, train loss 1.184272, train error 40.25,  test loss 1.486163, test error 52.70
# Epoch   600, train loss 1.171722, train error 39.55,  test loss 1.488732, test error 52.12
# Epoch   700, train loss 1.159237, train error 38.67,  test loss 1.510417, test error 51.97
# Epoch   800, train loss 1.165622, train error 39.67,  test loss 1.569906, test error 52.88
# Epoch   900, train loss 1.144282, train error 38.62,  test loss 1.566040, test error 52.47
# Training model with  22 hidden variables
# Epoch     0, train loss 2.162560, train error 80.62,  test loss 2.145468, test error 80.53
# Epoch   100, train loss 1.211536, train error 39.50,  test loss 1.295231, test error 48.20
# Epoch   200, train loss 1.130229, train error 37.83,  test loss 1.377975, test error 49.62
# Epoch   300, train loss 1.078377, train error 37.60,  test loss 1.443799, test error 50.95
# Epoch   400, train loss 1.039707, train error 35.45,  test loss 1.485662, test error 50.20
# Epoch   500, train loss 1.017625, train error 34.30,  test loss 1.558341, test error 51.72
# Epoch   600, train loss 1.008694, train error 34.57,  test loss 1.594093, test error 51.85
# Epoch   700, train loss 0.998427, train error 34.32,  test loss 1.621631, test error 51.95
# Epoch   800, train loss 0.976219, train error 32.68,  test loss 1.626496, test error 51.60
# Epoch   900, train loss 0.973685, train error 33.10,  test loss 1.641569, test error 51.78
# Training model with  26 hidden variables
# Epoch     0, train loss 2.124846, train error 79.62,  test loss 2.072610, test error 77.78
# Epoch   100, train loss 1.188294, train error 39.30,  test loss 1.274278, test error 47.00
# Epoch   200, train loss 1.054485, train error 34.70,  test loss 1.374561, test error 49.40
# Epoch   300, train loss 1.011077, train error 34.10,  test loss 1.496563, test error 50.62
# Epoch   400, train loss 0.945085, train error 31.07,  test loss 1.582862, test error 51.55
# Epoch   500, train loss 0.893983, train error 30.22,  test loss 1.666768, test error 52.65
# Epoch   600, train loss 0.872645, train error 29.30,  test loss 1.744769, test error 52.22
# Epoch   700, train loss 0.840164, train error 28.25,  test loss 1.822597, test error 52.33
# Epoch   800, train loss 0.819154, train error 26.80,  test loss 1.932638, test error 52.50
# Epoch   900, train loss 0.822129, train error 27.75,  test loss 2.048749, test error 53.53
# Training model with  30 hidden variables
# Epoch     0, train loss 2.119007, train error 78.03,  test loss 2.078178, test error 77.47
# Epoch   100, train loss 1.109280, train error 37.33,  test loss 1.340963, test error 48.22
# Epoch   200, train loss 0.941378, train error 33.35,  test loss 1.557469, test error 51.45
# Epoch   300, train loss 0.842661, train error 29.18,  test loss 1.719224, test error 51.80
# Epoch   400, train loss 0.797412, train error 27.35,  test loss 1.879094, test error 52.17
# Epoch   500, train loss 0.775689, train error 27.32,  test loss 2.025247, test error 52.92
# Epoch   600, train loss 0.741656, train error 26.22,  test loss 2.167451, test error 54.28
# Epoch   700, train loss 0.706809, train error 24.65,  test loss 2.254728, test error 53.78
# Epoch   800, train loss 0.681354, train error 23.50,  test loss 2.382854, test error 54.22
# Epoch   900, train loss 0.675772, train error 23.88,  test loss 2.545067, test error 54.25
# Training model with  35 hidden variables
# Epoch     0, train loss 2.186067, train error 81.18,  test loss 2.173533, test error 81.50
# Epoch   100, train loss 0.994249, train error 31.95,  test loss 1.433369, test error 50.50
# Epoch   200, train loss 0.774902, train error 25.78,  test loss 1.787741, test error 52.78
# Epoch   300, train loss 0.667476, train error 22.00,  test loss 2.196983, test error 54.22
# Epoch   400, train loss 0.596759, train error 19.90,  test loss 2.574743, test error 55.47
# Epoch   500, train loss 0.539104, train error 18.43,  test loss 2.943249, test error 56.10
# Epoch   600, train loss 0.499004, train error 17.45,  test loss 3.370585, test error 56.38
# Epoch   700, train loss 0.489846, train error 17.28,  test loss 3.664167, test error 56.97
# Epoch   800, train loss 0.473748, train error 16.55,  test loss 4.049959, test error 56.75
# Epoch   900, train loss 0.494034, train error 18.30,  test loss 4.395991, test error 57.88
# Training model with  40 hidden variables
# Epoch     0, train loss 2.074309, train error 77.40,  test loss 2.039150, test error 75.78
# Epoch   100, train loss 0.917266, train error 29.93,  test loss 1.470663, test error 51.12
# Epoch   200, train loss 0.665528, train error 20.60,  test loss 1.910318, test error 53.12
# Epoch   300, train loss 0.517912, train error 16.78,  test loss 2.532753, test error 55.22
# Epoch   400, train loss 0.428735, train error 13.95,  test loss 3.257151, test error 56.95
# Epoch   500, train loss 0.398616, train error 13.10,  test loss 4.011289, test error 58.28
# Epoch   600, train loss 0.293448, train error 9.45,  test loss 4.831336, test error 58.15
# Epoch   700, train loss 0.330486, train error 11.65,  test loss 5.590727, test error 58.67
# Epoch   800, train loss 0.284741, train error 9.85,  test loss 6.345112, test error 58.67
# Epoch   900, train loss 0.246409, train error 8.55,  test loss 6.802170, test error 58.65
# Training model with  45 hidden variables
# Epoch     0, train loss 2.137465, train error 80.12,  test loss 2.098921, test error 79.72
# Epoch   100, train loss 0.812073, train error 25.22,  test loss 1.546881, test error 50.28
# Epoch   200, train loss 0.496032, train error 16.22,  test loss 2.441370, test error 54.15
# Epoch   300, train loss 0.265469, train error 7.32,  test loss 3.539962, test error 54.05
# Epoch   400, train loss 0.181893, train error 5.55,  test loss 4.942895, test error 55.47
# Epoch   500, train loss 0.133571, train error 4.35,  test loss 6.196602, test error 55.75
# Epoch   600, train loss 0.143610, train error 4.45,  test loss 7.458829, test error 55.83
# Epoch   700, train loss 0.010473, train error 0.00,  test loss 8.369994, test error 55.60
# Epoch   800, train loss 0.007177, train error 0.00,  test loss 9.012522, test error 55.80
# Epoch   900, train loss 0.005459, train error 0.00,  test loss 9.487392, test error 55.85
# Training model with  50 hidden variables
# Epoch     0, train loss 2.042071, train error 75.00,  test loss 1.993485, test error 75.95
# Epoch   100, train loss 0.746150, train error 24.12,  test loss 1.559344, test error 49.55
# Epoch   200, train loss 0.366970, train error 11.35,  test loss 2.612156, test error 54.25
# Epoch   300, train loss 0.156483, train error 4.28,  test loss 4.115049, test error 55.92
# Epoch   400, train loss 0.027107, train error 0.00,  test loss 5.577621, test error 55.70
# Epoch   500, train loss 0.010741, train error 0.00,  test loss 6.425782, test error 55.90
# Epoch   600, train loss 0.007128, train error 0.00,  test loss 6.969079, test error 55.95
# Epoch   700, train loss 0.005179, train error 0.00,  test loss 7.385019, test error 55.97
# Epoch   800, train loss 0.004016, train error 0.00,  test loss 7.727013, test error 56.03
# Epoch   900, train loss 0.003258, train error 0.00,  test loss 8.007689, test error 56.08
# Training model with  55 hidden variables
# Epoch     0, train loss 2.098403, train error 79.28,  test loss 2.047370, test error 78.22
# Epoch   100, train loss 0.622061, train error 18.85,  test loss 1.662765, test error 50.85
# Epoch   200, train loss 0.211054, train error 5.03,  test loss 3.069927, test error 55.12
# Epoch   300, train loss 0.035173, train error 0.03,  test loss 4.630450, test error 55.40
# Epoch   400, train loss 0.013921, train error 0.00,  test loss 5.615718, test error 55.50
# Epoch   500, train loss 0.008202, train error 0.00,  test loss 6.208440, test error 55.70
# Epoch   600, train loss 0.005691, train error 0.00,  test loss 6.627044, test error 56.08
# Epoch   700, train loss 0.004278, train error 0.00,  test loss 6.952451, test error 56.05
# Epoch   800, train loss 0.003395, train error 0.00,  test loss 7.219026, test error 55.97
# Epoch   900, train loss 0.002778, train error 0.00,  test loss 7.448953, test error 56.00
# Training model with  60 hidden variables
# Epoch     0, train loss 2.065939, train error 76.25,  test loss 2.008905, test error 74.50
# Epoch   100, train loss 0.521308, train error 16.07,  test loss 1.751696, test error 51.20
# Epoch   200, train loss 0.084786, train error 0.53,  test loss 3.368787, test error 53.67
# Epoch   300, train loss 0.018114, train error 0.00,  test loss 4.592603, test error 54.33
# Epoch   400, train loss 0.008987, train error 0.00,  test loss 5.223468, test error 53.90
# Epoch   500, train loss 0.005680, train error 0.00,  test loss 5.648515, test error 54.10
# Epoch   600, train loss 0.004105, train error 0.00,  test loss 5.963574, test error 54.17
# Epoch   700, train loss 0.003146, train error 0.00,  test loss 6.213136, test error 54.17
# Epoch   800, train loss 0.002533, train error 0.00,  test loss 6.422347, test error 54.50
# Epoch   900, train loss 0.002110, train error 0.00,  test loss 6.598615, test error 54.33
# Training model with  70 hidden variables
# Epoch     0, train loss 2.006141, train error 74.95,  test loss 1.946135, test error 74.43
# Epoch   100, train loss 0.338490, train error 7.72,  test loss 1.948909, test error 50.97
# Epoch   200, train loss 0.030400, train error 0.00,  test loss 3.612165, test error 53.47
# Epoch   300, train loss 0.010241, train error 0.00,  test loss 4.353904, test error 53.35
# Epoch   400, train loss 0.005793, train error 0.00,  test loss 4.784912, test error 53.50
# Epoch   500, train loss 0.003918, train error 0.00,  test loss 5.083907, test error 53.72
# Epoch   600, train loss 0.002902, train error 0.00,  test loss 5.309759, test error 53.83
# Epoch   700, train loss 0.002281, train error 0.00,  test loss 5.492939, test error 53.85
# Epoch   800, train loss 0.001867, train error 0.00,  test loss 5.647165, test error 53.97
# Epoch   900, train loss 0.001572, train error 0.00,  test loss 5.779037, test error 54.12
# Training model with  80 hidden variables
# Epoch     0, train loss 2.010368, train error 74.68,  test loss 1.955393, test error 75.10
# Epoch   100, train loss 0.245595, train error 4.75,  test loss 2.033645, test error 50.35
# Epoch   200, train loss 0.021506, train error 0.00,  test loss 3.372460, test error 51.42
# Epoch   300, train loss 0.008404, train error 0.00,  test loss 3.934548, test error 51.10
# Epoch   400, train loss 0.004970, train error 0.00,  test loss 4.272406, test error 51.05
# Epoch   500, train loss 0.003395, train error 0.00,  test loss 4.512094, test error 50.97
# Epoch   600, train loss 0.002554, train error 0.00,  test loss 4.694257, test error 50.97
# Epoch   700, train loss 0.002022, train error 0.00,  test loss 4.846618, test error 50.97
# Epoch   800, train loss 0.001663, train error 0.00,  test loss 4.972026, test error 50.95
# Epoch   900, train loss 0.001405, train error 0.00,  test loss 5.081954, test error 50.88
# Training model with  90 hidden variables
# Epoch     0, train loss 1.996073, train error 73.88,  test loss 1.929185, test error 73.60
# Epoch   100, train loss 0.138270, train error 1.10,  test loss 2.192377, test error 51.38
# Epoch   200, train loss 0.015199, train error 0.00,  test loss 3.293206, test error 51.65
# Epoch   300, train loss 0.006745, train error 0.00,  test loss 3.744687, test error 51.62
# Epoch   400, train loss 0.004103, train error 0.00,  test loss 4.029911, test error 51.78
# Epoch   500, train loss 0.002887, train error 0.00,  test loss 4.234361, test error 51.90
# Epoch   600, train loss 0.002194, train error 0.00,  test loss 4.392066, test error 51.97
# Epoch   700, train loss 0.001754, train error 0.00,  test loss 4.522799, test error 51.95
# Epoch   800, train loss 0.001451, train error 0.00,  test loss 4.631942, test error 51.97
# Epoch   900, train loss 0.001232, train error 0.00,  test loss 4.726956, test error 51.92
# Training model with 100 hidden variables
# Epoch     0, train loss 1.999564, train error 74.22,  test loss 1.923348, test error 74.68
# Epoch   100, train loss 0.086786, train error 0.15,  test loss 2.210801, test error 50.40
# Epoch   200, train loss 0.012124, train error 0.00,  test loss 3.047318, test error 50.83
# Epoch   300, train loss 0.005589, train error 0.00,  test loss 3.400924, test error 50.83
# Epoch   400, train loss 0.003495, train error 0.00,  test loss 3.624707, test error 50.83
# Epoch   500, train loss 0.002482, train error 0.00,  test loss 3.787354, test error 50.78
# Epoch   600, train loss 0.001899, train error 0.00,  test loss 3.916872, test error 50.90
# Epoch   700, train loss 0.001527, train error 0.00,  test loss 4.023560, test error 51.03
# Epoch   800, train loss 0.001269, train error 0.00,  test loss 4.114372, test error 51.10
# Epoch   900, train loss 0.001080, train error 0.00,  test loss 4.192850, test error 51.05
# Training model with 120 hidden variables
# Epoch     0, train loss 1.988967, train error 74.62,  test loss 1.914970, test error 75.30
# Epoch   100, train loss 0.051939, train error 0.00,  test loss 2.263875, test error 50.97
# Epoch   200, train loss 0.009600, train error 0.00,  test loss 2.896659, test error 50.95
# Epoch   300, train loss 0.004730, train error 0.00,  test loss 3.184989, test error 51.30
# Epoch   400, train loss 0.003025, train error 0.00,  test loss 3.371897, test error 51.25
# Epoch   500, train loss 0.002180, train error 0.00,  test loss 3.507734, test error 51.30
# Epoch   600, train loss 0.001684, train error 0.00,  test loss 3.616099, test error 51.28
# Epoch   700, train loss 0.001362, train error 0.00,  test loss 3.706755, test error 51.35
# Epoch   800, train loss 0.001136, train error 0.00,  test loss 3.782606, test error 51.53
# Epoch   900, train loss 0.000971, train error 0.00,  test loss 3.849907, test error 51.55
# Training model with 140 hidden variables
# Epoch     0, train loss 1.954782, train error 72.70,  test loss 1.906259, test error 74.88
# Epoch   100, train loss 0.035250, train error 0.00,  test loss 2.159002, test error 50.67
# Epoch   200, train loss 0.007992, train error 0.00,  test loss 2.632902, test error 50.67
# Epoch   300, train loss 0.004120, train error 0.00,  test loss 2.861335, test error 50.40
# Epoch   400, train loss 0.002678, train error 0.00,  test loss 3.010572, test error 50.42
# Epoch   500, train loss 0.001949, train error 0.00,  test loss 3.123516, test error 50.33
# Epoch   600, train loss 0.001517, train error 0.00,  test loss 3.212217, test error 50.28
# Epoch   700, train loss 0.001232, train error 0.00,  test loss 3.287176, test error 50.30
# Epoch   800, train loss 0.001032, train error 0.00,  test loss 3.349690, test error 50.30
# Epoch   900, train loss 0.000885, train error 0.00,  test loss 3.405007, test error 50.30
# Training model with 160 hidden variables
# Epoch     0, train loss 1.958542, train error 71.62,  test loss 1.913305, test error 73.28
# Epoch   100, train loss 0.029093, train error 0.00,  test loss 2.098676, test error 47.60
# Epoch   200, train loss 0.007171, train error 0.00,  test loss 2.502115, test error 47.53
# Epoch   300, train loss 0.003765, train error 0.00,  test loss 2.695572, test error 47.47
# Epoch   400, train loss 0.002473, train error 0.00,  test loss 2.826717, test error 47.70
# Epoch   500, train loss 0.001810, train error 0.00,  test loss 2.923760, test error 47.47
# Epoch   600, train loss 0.001413, train error 0.00,  test loss 3.000999, test error 47.58
# Epoch   700, train loss 0.001151, train error 0.00,  test loss 3.065278, test error 47.53
# Epoch   800, train loss 0.000966, train error 0.00,  test loss 3.121310, test error 47.65
# Epoch   900, train loss 0.000829, train error 0.00,  test loss 3.169615, test error 47.60
# Training model with 180 hidden variables
# Epoch     0, train loss 1.899648, train error 68.70,  test loss 1.817777, test error 70.57
# Epoch   100, train loss 0.023950, train error 0.00,  test loss 2.083510, test error 48.88
# Epoch   200, train loss 0.006512, train error 0.00,  test loss 2.441492, test error 48.65
# Epoch   300, train loss 0.003493, train error 0.00,  test loss 2.619555, test error 48.72
# Epoch   400, train loss 0.002313, train error 0.00,  test loss 2.737619, test error 48.80
# Epoch   500, train loss 0.001703, train error 0.00,  test loss 2.825598, test error 48.75
# Epoch   600, train loss 0.001335, train error 0.00,  test loss 2.896792, test error 48.88
# Epoch   700, train loss 0.001090, train error 0.00,  test loss 2.955856, test error 48.85
# Epoch   800, train loss 0.000917, train error 0.00,  test loss 3.006805, test error 48.85
# Epoch   900, train loss 0.000788, train error 0.00,  test loss 3.051592, test error 48.85
# Training model with 200 hidden variables
# Epoch     0, train loss 1.905140, train error 69.60,  test loss 1.822797, test error 70.95
# Epoch   100, train loss 0.020527, train error 0.00,  test loss 1.997480, test error 48.25
# Epoch   200, train loss 0.005909, train error 0.00,  test loss 2.290447, test error 48.08
# Epoch   300, train loss 0.003227, train error 0.00,  test loss 2.448767, test error 48.20
# Epoch   400, train loss 0.002159, train error 0.00,  test loss 2.552136, test error 48.33
# Epoch   500, train loss 0.001597, train error 0.00,  test loss 2.632072, test error 48.38
# Epoch   600, train loss 0.001255, train error 0.00,  test loss 2.696116, test error 48.33
# Epoch   700, train loss 0.001028, train error 0.00,  test loss 2.749408, test error 48.38
# Epoch   800, train loss 0.000866, train error 0.00,  test loss 2.795495, test error 48.28
# Epoch   900, train loss 0.000746, train error 0.00,  test loss 2.835449, test error 48.33
# Training model with 250 hidden variables
# Epoch     0, train loss 1.907462, train error 69.30,  test loss 1.833988, test error 71.10
# Epoch   100, train loss 0.016742, train error 0.00,  test loss 1.963961, test error 47.65
# Epoch   200, train loss 0.005293, train error 0.00,  test loss 2.219025, test error 47.53
# Epoch   300, train loss 0.002949, train error 0.00,  test loss 2.353614, test error 47.45
# Epoch   400, train loss 0.001994, train error 0.00,  test loss 2.445347, test error 47.33
# Epoch   500, train loss 0.001485, train error 0.00,  test loss 2.515955, test error 47.35
# Epoch   600, train loss 0.001172, train error 0.00,  test loss 2.572996, test error 47.28
# Epoch   700, train loss 0.000963, train error 0.00,  test loss 2.620973, test error 47.15
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.661489, test error 47.15
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.697622, test error 47.08
# Training model with 300 hidden variables
# Epoch     0, train loss 1.854120, train error 67.03,  test loss 1.793696, test error 69.47
# Epoch   100, train loss 0.014130, train error 0.00,  test loss 1.870380, test error 46.67
# Epoch   200, train loss 0.004726, train error 0.00,  test loss 2.089417, test error 46.62
# Epoch   300, train loss 0.002678, train error 0.00,  test loss 2.205431, test error 46.83
# Epoch   400, train loss 0.001826, train error 0.00,  test loss 2.287895, test error 46.80
# Epoch   500, train loss 0.001366, train error 0.00,  test loss 2.349869, test error 46.75
# Epoch   600, train loss 0.001082, train error 0.00,  test loss 2.399755, test error 46.85
# Epoch   700, train loss 0.000891, train error 0.00,  test loss 2.442187, test error 46.88
# Epoch   800, train loss 0.000754, train error 0.00,  test loss 2.478702, test error 46.78
# Epoch   900, train loss 0.000652, train error 0.00,  test loss 2.510446, test error 46.72
# Training model with 400 hidden variables
# Epoch     0, train loss 1.844335, train error 65.60,  test loss 1.791168, test error 68.12
# Epoch   100, train loss 0.011749, train error 0.00,  test loss 1.769316, test error 46.28
# Epoch   200, train loss 0.004180, train error 0.00,  test loss 1.946992, test error 46.00
# Epoch   300, train loss 0.002418, train error 0.00,  test loss 2.044848, test error 45.80
# Epoch   400, train loss 0.001667, train error 0.00,  test loss 2.113094, test error 45.85
# Epoch   500, train loss 0.001255, train error 0.00,  test loss 2.165398, test error 45.65
# Epoch   600, train loss 0.000999, train error 0.00,  test loss 2.208203, test error 45.72
# Epoch   700, train loss 0.000825, train error 0.00,  test loss 2.243743, test error 45.67
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.274688, test error 45.65
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.301662, test error 45.60

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
